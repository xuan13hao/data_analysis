# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = 'taxa_abund_P8_P11_P14_P28_PHYLUM.csv'
data_df = pd.read_csv(file_path)

# Identify columns associated with different DOLs and map them
dol_mapping = {
    'P8': ['2', '11', '22', '25', '40', '46'],
    'P11': ['073A', '075A', '081A', '083A', '085A', '088A', '097A', '105A', '106A', '107A'],
    'P14': ['137A', '140A', '146A', '151A', '156A', '158A', '161A', '162A', '167A', '235A', '258A', '259A', '260A', '261A'],
    'P28': ['111A', '115A', '119A', '120A', '124A', '129A', '134A', '135A']
}

# Clean data: Remove non-numeric values, strip spaces, convert columns to integers
data_df = data_df.rename(columns=lambda x: x.strip())
for col in data_df.columns[1:]:  # Skipping the first column for now
    data_df[col] = data_df[col].astype(str).str.strip()
    data_df[col] = pd.to_numeric(data_df[col], errors='coerce')

data_df.fillna(0, inplace=True)
data_df = data_df.astype({col: int for col in data_df.columns[1:]})

# Sum up the counts by DOL for each bacteria type
dol_sums = {dol: data_df.set_index("class")[cols].sum(axis=1) for dol, cols in dol_mapping.items()}
data_df.set_index(data_df.columns[0], inplace=True)

data_df
# Out:
#                      2     11     22     25     40     46   073A   075A
# class
# Actinobacteria       0      0      0      0      0      3     36     23  \
# Bacteroidetes      262    247    121     86    124    133   2252    161
# Firmicutes       25948  17078  15080  18620  14877  15144  23822  25777
# Patescibacteria      0      0      0      0      0      0      0      0
# Proteobacteria     384   9272  11396   7891  11596  11317    487    636
# Tenericutes          3      0      0      0      0      0      0      0
# DOL                  0      0      0      0      0      0      0      0
# sample               2     11     22     25     40     46      0      0
#
#                   081A   083A  ...   167A   215A   226A   227A   228A   235A
# class                          ...
# Actinobacteria      12      0  ...    135      0      0      0      0      0  \
# Bacteroidetes       26    410  ...   7829  14251     56     29      0     37
# Firmicutes       25720  25467  ...  18478  12318  16080  13179  12232  20114
# Patescibacteria      0      0  ...      0      0      0      0      0      0
# Proteobacteria     839    720  ...    146     28  10461  13389  14365   6446
# Tenericutes          0      0  ...      9      0      0      0      0      0
# DOL                  0      0  ...      0      0      0      0      0      0
# sample               0      0  ...      0      0      0      0      0      0
#
#                   258A   259A   260A   261A
# class
# Actinobacteria      55      4      0      0
# Bacteroidetes    15228  11376  12784  15518
# Firmicutes        9554  15119  13774  10924
# Patescibacteria      0      2      5      9
# Proteobacteria    1760     96      0    112
# Tenericutes          0      0     34     34
# DOL                  0      0      0      0
# sample               0      0      0      0
#
# [8 rows x 42 columns]

# %%
# Define color mapping
color_mapping = {
    'Firmicutes': '#FF6347',
    'Proteobacteria': '#4682B4',
    'Bacteroidetes': '#EE82EE',
    'Actinobacteria': '#F4A460',
    'Other': '#9ACD32'
}
# Calculate and plot the pie charts with the top 3 features and 'Other'
fig, axes = plt.subplots(2, 2, figsize=(14, 12))
for i, (dol, cols) in enumerate(dol_mapping.items()):
    ax = axes[i//2, i%2]
    sums = data_df[cols].sum(axis=1).sort_values(ascending=False)
    top_three = sums.head(3)
    other = pd.Series(sums[3:].sum(), index=['Other'])
    final_sums = pd.concat([top_three, other])
    
    # Assign colors according to the taxa, with a default color for 'Other'
    colors = [color_mapping.get(tax, color_mapping['Other']) for tax in final_sums.index]

    # wedges, texts, autotexts = ax.pie(final_sums, labels=final_sums.index, autopct='%1.1f%%', startangle=140, colors=colors)
    wedges, texts, autotexts = ax.pie(final_sums, labels=None, autopct='%1.1f%%', startangle=140, colors=colors,pctdistance=1.12, labeldistance=2.2,shadow=True,textprops={'fontsize': 14, 'color': 'black'})
    ax.set_title(f'{dol}')
    # Add a legend outside the plot
    ax.legend(wedges, final_sums.index, title="", loc="center left", bbox_to_anchor=(0.89, 0.3, 0.5, 1), fontsize='large')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = 'taxa_abund_P8_P11_P14_P28_GENUS.csv'
data_df = pd.read_csv(file_path)

# Identify columns associated with different DOLs and map them
dol_mapping = {
    'P8': ['2', '11', '22', '25', '40', '46'],
    'P11': ['073A', '075A', '081A', '083A', '085A', '088A', '097A', '105A', '106A', '107A'],
    'P14': ['137A', '140A', '146A', '151A', '156A', '158A', '161A', '162A', '167A', '235A', '258A', '259A', '260A', '261A'],
    'P28': ['111A', '115A', '119A', '120A', '124A', '129A', '134A', '135A']
}

# Clean data: Remove non-numeric values, strip spaces, convert columns to integers
data_df = data_df.rename(columns=lambda x: x.strip())
for col in data_df.columns[1:]:  # Skipping the first column for now
    data_df[col] = data_df[col].astype(str).str.strip()
    data_df[col] = pd.to_numeric(data_df[col], errors='coerce')

data_df.fillna(0, inplace=True)
data_df = data_df.astype({col: int for col in data_df.columns[1:]})

# Sum up the counts by DOL for each bacteria type
dol_sums = {dol: data_df.set_index("class")[cols].sum(axis=1) for dol, cols in dol_mapping.items()}
data_df.set_index(data_df.columns[0], inplace=True)

data_df
# Out:
#                                    2     11     22     25     40     46
# class
# A2                                 0      0      0      0      0      0  \
# Acetatifactor                      0      0      0      0      0      0
# Alistipes                         32     24      8      2      9     11
# Anaeroplasma                       3      0      0      0      0      0
# Anaerotruncus                      3      2      1      1      2      0
# Angelakisella                      0      0      0      0      0      0
# ASF356                             0      0      0      0      0      0
# Bacteroides                       26     24     22      9      8     32
# Bifidobacterium                    0      0      0      0      0      3
# Butyricicoccus                     0      3      4      3      4      3
# Candidatus_Saccharimonas           0      0      0      0      0      0
# Clostridium_sensu_stricto_1        0      0      0      0      0      0
# Enterococcus                       5      7      0      0      8      4
# Enterorhabdus                      0      0      0      0      0      0
# Escherichia_Shigella              22   9148  11034   7829  11488  11100
# Faecalibaculum                     0      0      0      0      0      2
# GCA_900066575                      0      0      0      0      0      0
# Intestinimonas                     0      0      0      0      9      0
# Lachnoclostridium                  4      0      5      0      0      2
# Lachnospiraceae_FCS020_group       0      0      0      0      0      0
# Lachnospiraceae_NK4A136_group     26     27     15     15     16     24
# Lachnospiraceae_UCG_006            0      0      0      0      0      0
# Lactobacillus                  23078  16702  14708  18266  14199  14468
# Marvinbryantia                     0      0      0      0      0      0
# Muribacter                       362    124    362     62    108    217
# Muribaculum                        0      0      0      0      0      0
# Not_Assigned                     191    170     78     54     92     73
# Odoribacter                        0      0      0      0      0      2
# Oscillibacter                      2      6      1      0      3      4
# Parabacteroides                    0      0      0      0      0      0
# Parasutterella                     0      0      0      0      0      0
# Prevotellaceae_UCG_001            13     17      9     14     10     12
# Pseudomonas                        0      0      0      0      0      0
# Rikenellaceae_RC9_gut_group       12     18     14      7     11     11
# Romboutsia                         0      0      0      0      5      0
# Roseburia                          0      0      0      0      0      0
# Ruminiclostridium                  0      0      0      0      0      0
# Ruminiclostridium_5                0      0      0      0      0      0
# Ruminiclostridium_9               19     10     10      1      5      4
# Staphylococcus                  1199     43     18      7      6      0
# Streptococcus                   1600    272    308    327    613    625
# Turicibacter                       0      0      0      0      1      0
# Tyzzerella                         0      0      0      0      0      0
# DOL                                0      0      0      0      0      0
# sample                             2     11     22     25     40     46
#
#                                 073A   075A   081A   083A  ...   167A   215A
# class                                                      ...
# A2                               192      9      0      0  ...      0      0  \
# Acetatifactor                     11      0      0      0  ...      0      0
# Alistipes                          0      0      0      0  ...    101      0
# Anaeroplasma                       0      0      0      0  ...      9      0
# Anaerotruncus                    696    570      4     14  ...     16    177
# Angelakisella                     29      0      0      0  ...    124      0
# ASF356                             6     64      0      0  ...      0      0
# Bacteroides                        0      0      0      0  ...      0   4856
# Bifidobacterium                    0      0      6      0  ...      0      0
# Butyricicoccus                     0      0      0      0  ...      0      0
# Candidatus_Saccharimonas           0      0      0      0  ...      0      0
# Clostridium_sensu_stricto_1       14     17      0      0  ...     10      0
# Enterococcus                    1092    172     30    246  ...    665    181
# Enterorhabdus                     36     23      6      0  ...    135      0
# Escherichia_Shigella              46     54      0      0  ...     16      7
# Faecalibaculum                     0      0     26      9  ...      3      0
# GCA_900066575                      0      0      0      0  ...     17      0
# Intestinimonas                     0      0      4      0  ...     31      0
# Lachnoclostridium                 12     54      0      0  ...    129    142
# Lachnospiraceae_FCS020_group      14      0      0      0  ...      0      0
# Lachnospiraceae_NK4A136_group     14     41     69     47  ...     15   3724
# Lachnospiraceae_UCG_006          210     33      0      0  ...      0      0
# Lactobacillus                  17137  21953  23716  23167  ...  13203   5111
# Marvinbryantia                    23      0      0      8  ...     64      9
# Muribacter                        77    569    832    686  ...    114     21
# Muribaculum                        0      0      0    350  ...    720     17
# Not_Assigned                    3722   1174    352    526  ...   7730  10887
# Odoribacter                        0      0      0      0  ...      0      0
# Oscillibacter                     43      0      0      0  ...     23    182
# Parabacteroides                   12      1      0      0  ...      2     27
# Parasutterella                   359      0      0     34  ...      0      0
# Prevotellaceae_UCG_001             0      0      0      0  ...      7     69
# Pseudomonas                        5     13      7      0  ...     16      0
# Rikenellaceae_RC9_gut_group      329      0     15     54  ...   2796    804
# Romboutsia                         0      0     16      0  ...      0      0
# Roseburia                          0     24     13      3  ...    234      0
# Ruminiclostridium                  4      0      0      0  ...      0     22
# Ruminiclostridium_5               15      0      0      0  ...      3      0
# Ruminiclostridium_9               53      2      0     12  ...    194      8
# Staphylococcus                    24     19    260    384  ...      0     41
# Streptococcus                   2422   1778   1241   1047  ...    155    312
# Turicibacter                       0      0      0     10  ...      0      0
# Tyzzerella                         0     27      0      0  ...     65      0
# DOL                                0      0      0      0  ...      0      0
# sample                             0      0      0      0  ...      0      0
#
#                                 226A   227A   228A   235A  258A  259A  260A
# class
# A2                                 0      0      0      0     0     0     0  \
# Acetatifactor                      0      0      0      0     0    13     0
# Alistipes                          5      7      0      0     0   691  1261
# Anaeroplasma                       0      0      0      0     0     0    34
# Anaerotruncus                    157      0      0      0    18   130   116
# Angelakisella                      0      0      0      0    37   284   136
# ASF356                             0      0      0      0     0     0     9
# Bacteroides                       42     22      0     37  6573  4340  1258
# Bifidobacterium                    0      0      0      0    55     4     0
# Butyricicoccus                     0      0      0      0     0     0     0
# Candidatus_Saccharimonas           0      0      0      0     0     2     5
# Clostridium_sensu_stricto_1        3      0      0      0     0     0    25
# Enterococcus                     124     39    108      0  2001     0    21
# Enterorhabdus                      0      0      0      0     0     0     0
# Escherichia_Shigella           10290  13252  14365   6107     0     0     0
# Faecalibaculum                     0      0      0      0   154     0     0
# GCA_900066575                      0      0      0      0     0   164    22
# Intestinimonas                     0      0      0      0     0   379   224
# Lachnoclostridium                 32      0      0      0     0   406   175
# Lachnospiraceae_FCS020_group       0      0      0      0     0     0     0
# Lachnospiraceae_NK4A136_group     13    155      0      0     6   118    82
# Lachnospiraceae_UCG_006            0      0      0      0     0    14     9
# Lactobacillus                  14363  11360  11742  18344  4664  9191  9459
# Marvinbryantia                     0      0      0      0     0    75    20
# Muribacter                       171    137      0    339  1760     0     0
# Muribaculum                        0      0      0      0     0     0    91
# Not_Assigned                     189    352     76     27     1  5974  8904
# Odoribacter                        0      0      0      0     0   806   841
# Oscillibacter                      0      0      3      0     0   376   142
# Parabacteroides                    9      0      0      0  8617  1469   585
# Parasutterella                     0      0      0      0     0    96     0
# Prevotellaceae_UCG_001             0      0      0      0     0   143   239
# Pseudomonas                        0      0      0      0     0     0     0
# Rikenellaceae_RC9_gut_group        0      0      0      0    38   577  1443
# Romboutsia                        32      0      0      0     0     0     0
# Roseburia                          0      0      0      0     0   419   155
# Ruminiclostridium                  0      0      0      0     0    42    38
# Ruminiclostridium_5                0      0      0      0     0    47   115
# Ruminiclostridium_9                0      0      0      0     0   113    48
# Staphylococcus                     0      0      0     20  1671   258   246
# Streptococcus                   1167   1273    303   1723   957   436   875
# Turicibacter                       0      0      0      0    45     0     0
# Tyzzerella                         0      0      0      0     0    30    19
# DOL                                0      0      0      0     0     0     0
# sample                             0      0      0      0     0     0     0
#
#                                261A
# class
# A2                                0
# Acetatifactor                     8
# Alistipes                      1035
# Anaeroplasma                     34
# Anaerotruncus                    75
# Angelakisella                    73
# ASF356                            0
# Bacteroides                    4563
# Bifidobacterium                   0
# Butyricicoccus                    0
# Candidatus_Saccharimonas          9
# Clostridium_sensu_stricto_1      13
# Enterococcus                      0
# Enterorhabdus                     0
# Escherichia_Shigella              0
# Faecalibaculum                    0
# GCA_900066575                    31
# Intestinimonas                  136
# Lachnoclostridium               124
# Lachnospiraceae_FCS020_group      0
# Lachnospiraceae_NK4A136_group  1327
# Lachnospiraceae_UCG_006          50
# Lactobacillus                  7009
# Marvinbryantia                   96
# Muribacter                        0
# Muribaculum                       0
# Not_Assigned                   7314
# Odoribacter                     690
# Oscillibacter                    57
# Parabacteroides                1405
# Parasutterella                  112
# Prevotellaceae_UCG_001          350
# Pseudomonas                       0
# Rikenellaceae_RC9_gut_group    1182
# Romboutsia                       25
# Roseburia                       185
# Ruminiclostridium                30
# Ruminiclostridium_5              17
# Ruminiclostridium_9              26
# Staphylococcus                  171
# Streptococcus                   431
# Turicibacter                      0
# Tyzzerella                       19
# DOL                               0
# sample                            0
#
# [45 rows x 42 columns]

# %%
'''
colors = []
for tax in top_five_taxa:
    if tax == 'Lactobacillus':
        colors.append('#FF6347')
    elif tax == 'Escherichia_Shigella':
        colors.append('#4682B4')
    elif tax == 'Not_Assigned':
        colors.append('#FFE4C4')
    elif tax == 'Muribacter':
        colors.append('#F4A460')
    else:
        colors.append('#9ACD32')
'''

# Define color mapping
color_mapping = {
    'Lactobacillus': '#FF6347',
    'Escherichia_Shigella': '#4682B4',
    'Not_Assigned': '#1111B1',
    'Bacteroides': '#EE82EE',
    'Streptococcus': '#F4A460',
    'Muribacter': '#FFFF00',
    'Lachnospiraceae_NK4A136_group': '#8A2BE2',
    'Other': '#9ACD32'
}
# Calculate and plot the pie charts with the top 3 features and 'Other'
fig, axes = plt.subplots(2, 2, figsize=(14, 12))
for i, (dol, cols) in enumerate(dol_mapping.items()):
    ax = axes[i//2, i%2]
    sums = data_df[cols].sum(axis=1).sort_values(ascending=False)
    top_three = sums.head(3)
    other = pd.Series(sums[3:].sum(), index=['Other'])
    final_sums = pd.concat([top_three, other])
    
    # Assign colors according to the taxa, with a default color for 'Other'
    colors = [color_mapping.get(tax, color_mapping['Other']) for tax in final_sums.index]

    # wedges, texts, autotexts = ax.pie(final_sums, labels=final_sums.index, autopct='%1.1f%%', startangle=140, colors=colors)
    wedges, texts, autotexts = ax.pie(final_sums, labels=None, autopct='%1.1f%%', startangle=140, colors=colors, pctdistance=1.16, labeldistance=2.2,shadow=True,textprops={'fontsize': 14, 'color': 'black'})
    ax.set_title(f'{dol}')
    # Add a legend outside the plot
    ax.legend(wedges, final_sums.index, title="", loc="center left", bbox_to_anchor=(0.89, 0.3, 0.5, 1), fontsize='large')

plt.tight_layout()
plt.show()
