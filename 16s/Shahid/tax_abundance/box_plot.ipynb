# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample data (replace this with your actual data)
data = {
    'sample': [4, 5, 6, 9, 10, 16, 17, 18, 19, 20, 21, 26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39, 44, 45],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_WT', 'Sig_Homo_HET'],
    'Bacteroidetes': [2322, 1730, 5378, 1645, 877, 1307, 3764, 612, 1884, 2087, 3287, 4191, 1604, 1853, 1002, 2527, 1324, 2301, 3364, 5626, 2913, 10079, 4007, 4956, 2362, 2407],
    'Firmicutes': [3503, 10665, 4499, 14590, 10228, 3654, 3019, 10139, 5071, 21505, 11880, 7603, 3859, 10796, 16153, 1103, 14177, 4323, 1661, 37909, 50769, 8071, 54385, 49641, 23995, 6125],
    'Others': [476, 354, 1103, 245, 181, 315, 690, 151, 477, 451, 634, 958, 350, 377, 197, 485, 272, 418, 549, 1170, 607, 2059, 716, 776, 414, 423],
    'Proteobacteria': [55637, 49189, 50958, 45458, 50652, 56662, 54465, 51036, 54506, 37895, 46137, 49186, 56125, 48912, 44586, 57823, 46165, 54896, 56364, 17233, 7649, 41729, 2830, 6565, 35167, 52983]
}

df = pd.DataFrame(data)

# Box plot based on Genotype types
plt.figure(figsize=(15, 9))
box_plot = df.boxplot(column=['Bacteroidetes', 'Firmicutes', 'Others', 'Proteobacteria'], by='Genotype', grid=False)

# Customize the plot
# plt.title('Box Plot of Genotype Types')
plt.suptitle('')  # Remove the default title
plt.xlabel('Genotype')
plt.ylabel('Abundance')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
#feeding
# Sample data (replace this with your actual data)
data_F = {
    'sample': [4, 5, 6, 9, 10, 16, 17, 18, 19, 20, 21, 26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39, 44, 45],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_WT', 'Sig_Homo_HET'],
    # 'Bacteroidetes': [2322, 1730, 5378, 1645, 877, 1307, 3764, 612, 1884, 2087, 3287, 4191, 1604, 1853, 1002, 2527, 1324, 2301, 3364, 5626, 2913, 10079, 4007, 4956, 2362, 2407],
    'Firmicutes': [3482, 10665, 4492, 14590, 10229, 3658, 3020, 10144, 5078, 21516, 11852, 7605, 3862, 10799, 16158, 1093, 14152, 4319, 1661, 37901, 50775, 8062, 54346, 49647, 23995, 6121],
    # 'Others': [476, 354, 1103, 245, 181, 315, 690, 151, 477, 451, 634, 958, 350, 377, 197, 485, 272, 418, 549, 1170, 607, 2059, 716, 776, 414, 423],
    # 'Proteobacteria': [55637, 49189, 50958, 45458, 50652, 56662, 54465, 51036, 54506, 37895, 46137, 49186, 56125, 48912, 44586, 57823, 46165, 54896, 56364, 17233, 7649, 41729, 2830, 6565, 35167, 52983]
}
data_C = {
    'sample': [1, 2, 3, 7, 8, 11, 13, 14, 15, 22, 23, 24, 25, 30, 40, 41, 42, 43, 46, 47, 48, 49],
    # 'Bacteroidetes': [346, 617, 429, 460, 454, 543, 300, 338, 230, 272, 215, 304, 214, 74, 329, 1301, 226, 205, 355, 221, 416, 388],
    'Firmicutes': [48175, 48021, 48115, 47619, 47586, 31676, 26791, 27625, 29322, 28326, 33965, 34591, 34651, 35086, 27555, 37507, 34450, 27580, 28236, 27356, 44685, 39687],
    # 'Others': [74, 158, 98, 71, 108, 106, 52, 80, 36, 92, 47, 68, 62, 28, 114, 267, 47, 52, 58, 38, 59, 89],
    # 'Proteobacteria': [1266, 1065, 1219, 1711, 1713, 17536, 22718, 21818, 20273, 21171, 15634, 14898, 14934, 14673, 21863, 10786, 15138, 22024, 21212, 22246, 4701, 9697],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_Homo_HET']
}
df_F = pd.DataFrame(data_F)
df_C = pd.DataFrame(data_C)
# Melt the dataframe for easy plotting value_vars=['Bacteroidetes', 'Firmicutes', 'Others', 'Proteobacteria']
df_melted_F = pd.melt(df_F, id_vars=['Genotype'], value_vars=['Firmicutes'],
                    var_name='Bacterial Species', value_name='Abundance')
df_melted_C = pd.melt(df_C, id_vars=['Genotype'], value_vars=['Firmicutes'],
                    var_name='Bacterial Species', value_name='Abundance')
# Box plot for all data in one figure
plt.figure(figsize=(12, 8))
sns.boxplot(x='Genotype', y='Abundance', hue='Bacterial Species', data=df_melted)
plt.title('Box Plot of Genotype Types for Bacterial Species Abundance')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
#control
# Sample data (replace this with your actual data)
data = {
    'sample': [1, 2, 3, 7, 8, 11, 13, 14, 15, 22, 23, 24, 25, 30, 40, 41, 42, 43, 46, 47, 48, 49],
    # 'Bacteroidetes': [346, 617, 429, 460, 454, 543, 300, 338, 230, 272, 215, 304, 214, 74, 329, 1301, 226, 205, 355, 221, 416, 388],
    'Firmicutes': [48175, 48021, 48115, 47619, 47586, 31676, 26791, 27625, 29322, 28326, 33965, 34591, 34651, 35086, 27555, 37507, 34450, 27580, 28236, 27356, 44685, 39687],
    # 'Others': [74, 158, 98, 71, 108, 106, 52, 80, 36, 92, 47, 68, 62, 28, 114, 267, 47, 52, 58, 38, 59, 89],
    # 'Proteobacteria': [1266, 1065, 1219, 1711, 1713, 17536, 22718, 21818, 20273, 21171, 15634, 14898, 14934, 14673, 21863, 10786, 15138, 22024, 21212, 22246, 4701, 9697],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_Homo_HET']
}

df = pd.DataFrame(data)

# Melt the dataframe for easy plotting
df_melted = pd.melt(df, id_vars=['Genotype'], value_vars=['Firmicutes'],
                    var_name='Bacterial Species', value_name='Abundance')

# Box plot for all data in one figure
plt.figure(figsize=(12, 8))
sns.boxplot(x='Genotype', y='Abundance', hue='Bacterial Species', data=df_melted)
plt.title('Box Plot of Genotype Types for Bacterial Species Abundance')
plt.ylabel('Abundance')  # Add y-axis label for clarity

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data for feeding
data_F = {
    'sample': [4, 5, 6, 9, 10, 16, 17, 18, 19, 20, 21, 26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39, 44, 45],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_WT', 'Sig_Homo_HET'],
    'Firmicutes': [3482, 10665, 4492, 14590, 10229, 3658, 3020, 10144, 5078, 21516, 11852, 7605, 3862, 10799, 16158, 1093, 14152, 4319, 1661, 37901, 50775, 8062, 54346, 49647, 23995, 6121],
}

# Sample data for control
data_C = {
    'sample': [1, 2, 3, 7, 8, 11, 13, 14, 15, 22, 23, 24, 25, 30, 40, 41, 42, 43, 46, 47, 48, 49],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_Homo_HET'],
    'Firmicutes': [48175, 48021, 48115, 47619, 47586, 31676, 26791, 27625, 29322, 28326, 33965, 34591, 34651, 35086, 27555, 37507, 34450, 27580, 28236, 27356, 44685, 39687],
}

# Creating dataframes
df_F = pd.DataFrame(data_F)
df_C = pd.DataFrame(data_C)

# Melt the dataframes for easy plotting
df_melted_F = pd.melt(df_F, id_vars=['Genotype', 'sample'], value_vars=['Firmicutes'],
                    var_name='Bacterial Species', value_name='Abundance')
df_melted_C = pd.melt(df_C, id_vars=['Genotype', 'sample'], value_vars=['Firmicutes'],
                    var_name='Bacterial Species', value_name='Abundance')

# Box plot for feeding data
plt.figure(figsize=(12, 8))
sns.boxplot(x='Genotype', y='Abundance', data=df_melted_F)
plt.title('Box Plot of Genotype Types for Firmicutes Abundance - Feeding')
plt.ylabel('Abundance')  # Add y-axis label for clarity
plt.show()

# Box plot for control data
plt.figure(figsize=(12, 8))
sns.boxplot(x='Genotype', y='Abundance', data=df_melted_C)
plt.title('Box Plot of Genotype Types for Firmicutes Abundance - Control')
plt.ylabel('Abundance')  # Add y-axis label for clarity
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data for feeding
data_F = {
    'sample': [4, 5, 6, 9, 10, 16, 17, 18, 19, 20, 21, 26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39, 44, 45],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_WT', 'Sig_Homo_HET'],
    'Firmicutes': [3482, 10665, 4492, 14590, 10229, 3658, 3020, 10144, 5078, 21516, 11852, 7605, 3862, 10799, 16158, 1093, 14152, 4319, 1661, 37901, 50775, 8062, 54346, 49647, 23995, 6121],
}

# Sample data for control
data_C = {
    'sample': [1, 2, 3, 7, 8, 11, 13, 14, 15, 22, 23, 24, 25, 30, 40, 41, 42, 43, 46, 47, 48, 49],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_Homo_HET'],
    'Firmicutes': [48175, 48021, 48115, 47619, 47586, 31676, 26791, 27625, 29322, 28326, 33965, 34591, 34651, 35086, 27555, 37507, 34450, 27580, 28236, 27356, 44685, 39687],
}

# Creating dataframes
df_F = pd.DataFrame(data_F)
df_C = pd.DataFrame(data_C)

# Melt the dataframes for easy plotting
df_melted_F = pd.melt(df_F, id_vars=['Genotype', 'sample'], value_vars=['Firmicutes'],
                    var_name='Bacterial Species', value_name='Abundance')
df_melted_C = pd.melt(df_C, id_vars=['Genotype', 'sample'], value_vars=['Firmicutes'],
                    var_name='Bacterial Species', value_name='Abundance')

# Box plot for feeding and control data in the same plane
plt.figure(figsize=(15, 8))

# Subplot for feeding data
plt.subplot(1, 2, 1)
sns.boxplot(x='Genotype', y='Abundance', data=df_melted_F)
plt.title('Feeding - Firmicutes Abundance')
plt.ylabel('Abundance')  # Add y-axis label for clarity

# Subplot for control data
plt.subplot(1, 2, 2)
sns.boxplot(x='Genotype', y='Abundance', data=df_melted_C)
plt.title('Control - Firmicutes Abundance')
plt.ylabel('Abundance')  # Add y-axis label for clarity

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming df is your DataFrame
df = pd.read_csv('taxa_abund_CF_1.csv', index_col=0)
df = pd.DataFrame(df)
df
# # df.index
# # # # Set up the matplotlib figure
# plt.figure(figsize=(10, 6))

# # # # # # Create a boxplot
# sns.boxplot(x='Genotype', y='Firmicutes', hue='Type', data=df)

# # Show the plot
# plt.show()
# Out:
#                        4       5             6             9      10
# Firmicutes          3482   10665          4492         14590   10229  \
# Geno        Sig_Homo_HET  Sig_WT  Sig_Homo_HET  Sig_Homo_HET  Sig_WT
# Type                   F       F             F             F       F
#
#                       16            17      18            19      20  ...
# Firmicutes          3658          3020   10144          5078   21516  ...  \
# Geno        Sig_Homo_HET  Sig_Homo_HET  Sig_WT  Sig_Homo_HET  Sig_WT  ...
# Type                   F             F       F             F       F  ...
#
#                 25            30      40            41            42
# Firmicutes   34651         35086   27555         37507         34450  \
# Geno        Sig_WT  Sig_Homo_HET  Sig_WT  Sig_Homo_HET  Sig_Homo_HET
# Type             C             C       C             C             C
#
#                       43      46            47            48            49
# Firmicutes         27580   28236         27356         44685         39687
# Geno        Sig_Homo_HET  Sig_WT  Sig_Homo_HET  Sig_Homo_HET  Sig_Homo_HET
# Type                   C       C             C             C             C
#
# [3 rows x 48 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data for feeding
data_F = {
    'sample': [4, 5, 6, 9, 10, 16, 17, 18, 19, 20, 21, 26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39, 44, 45],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_WT', 'Sig_Homo_HET'],
    'Firmicutes': [3482, 10665, 4492, 14590, 10229, 3658, 3020, 10144, 5078, 21516, 11852, 7605, 3862, 10799, 16158, 1093, 14152, 4319, 1661, 37901, 50775, 8062, 54346, 49647, 23995, 6121],
}

# Sample data for control
data_C = {
    'sample': [1, 2, 3, 7, 8, 11, 13, 14, 15, 22, 23, 24, 25, 30, 40, 41, 42, 43, 46, 47, 48, 49],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_Homo_HET'],
    'Firmicutes': [48175, 48021, 48115, 47619, 47586, 31676, 26791, 27625, 29322, 28326, 33965, 34591, 34651, 35086, 27555, 37507, 34450, 27580, 28236, 27356, 44685, 39687],
}

# Combine feeding and control data into a single DataFrame
df_F = pd.DataFrame(data_F)
df_C = pd.DataFrame(data_C)
df_F['Group'] = 'Feeding'
df_C['Group'] = 'Control'
df_combined = pd.concat([df_F, df_C])

# Melt the combined DataFrame for easy plotting
df_melted_combined = pd.melt(df_combined, id_vars=['Group', 'Genotype', 'sample'], value_vars=['Firmicutes'],
                             var_name='Bacterial Species', value_name='Abundance')

# Box plot for feeding and control data on the same axis
plt.figure(figsize=(10, 6))
sns.boxplot(x='Group', y='Abundance', hue='Genotype', data=df_melted_combined)
plt.title('Firmicutes')
plt.ylabel('Abundance')  # Add y-axis label for clarity

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data for feeding
data_F = {
    'sample': [4, 5, 6, 9, 10, 16, 17, 18, 19, 20, 21, 26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39, 44, 45],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_WT', 'Sig_Homo_HET'],
    'Firmicutes': [3482, 10665, 4492, 14590, 10229, 3658, 3020, 10144, 5078, 21516, 11852, 7605, 3862, 10799, 16158, 1093, 14152, 4319, 1661, 37901, 50775, 8062, 54346, 49647, 23995, 6121],
}

# Sample data for control
data_C = {
    'sample': [1, 2, 3, 7, 8, 11, 13, 14, 15, 22, 23, 24, 25, 30, 40, 41, 42, 43, 46, 47, 48, 49],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_Homo_HET'],
    'Firmicutes': [48175, 48021, 48115, 47619, 47586, 31676, 26791, 27625, 29322, 28326, 33965, 34591, 34651, 35086, 27555, 37507, 34450, 27580, 28236, 27356, 44685, 39687],
}

# Combine feeding and control data into a single DataFrame
df_F = pd.DataFrame(data_F)
df_C = pd.DataFrame(data_C)
df_F['Dataset'] = 'Feeding'
df_C['Dataset'] = 'Control'
df_combined = pd.concat([df_C, df_F])  # Note the order change

# Melt the combined DataFrame for easy plotting
df_melted_combined = pd.melt(df_combined, id_vars=['Dataset', 'Genotype', 'sample'], value_vars=['Firmicutes'],
                             var_name='Bacterial Species', value_name='Abundance')

# Box plot for combined data with Control on the left and Feeding on the right
plt.figure(figsize=(15, 8))
sns.boxplot(x='Dataset', y='Abundance', hue='Genotype', data=df_melted_combined)
plt.title(' Firmicutes')
plt.ylabel('Abundance')  # Add y-axis label for clarity

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data for feeding
data_F = {
    'sample': [4, 5, 6, 9, 10, 16, 17, 18, 19, 20, 21, 26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39, 44, 45],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_WT', 'Sig_Homo_HET'],
    'Firmicutes': [3482, 10665, 4492, 14590, 10229, 3658, 3020, 10144, 5078, 21516, 11852, 7605, 3862, 10799, 16158, 1093, 14152, 4319, 1661, 37901, 50775, 8062, 54346, 49647, 23995, 6121],
}

# Sample data for control
data_C = {
    'sample': [1, 2, 3, 7, 8, 11, 13, 14, 15, 22, 23, 24, 25, 30, 40, 41, 42, 43, 46, 47, 48, 49],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_Homo_HET'],
    'Firmicutes': [48175, 48021, 48115, 47619, 47586, 31676, 26791, 27625, 29322, 28326, 33965, 34591, 34651, 35086, 27555, 37507, 34450, 27580, 28236, 27356, 44685, 39687],
}

# Combine feeding and control data into a single DataFrame
df_F = pd.DataFrame(data_F)
df_C = pd.DataFrame(data_C)
df_F['Dataset'] = 'Feeding'
df_C['Dataset'] = 'Control'
df_combined = pd.concat([df_C, df_F])  # Note the order change

# Melt the combined DataFrame for easy plotting
df_melted_combined = pd.melt(df_combined, id_vars=['Dataset', 'Genotype', 'sample'], value_vars=['Firmicutes'],
                             var_name='Bacterial Species', value_name='Abundance')

# Set specific colors for Genotype
colors = {'Sig_Homo_HET': '#F8766D',  # Light Blue
          'Sig_WT': '#00BFC4'}

# Box plot for combined data with Control on the left and Feeding on the right
plt.figure(figsize=(15, 8))
sns.boxplot(x='Dataset', y='Abundance', hue='Genotype', data=df_melted_combined, palette=colors)
plt.title('Firmicutes',fontsize = 18)
plt.ylabel('Abundance',fontsize = 18)  # Add y-axis label for clarity
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data
data = {
    'Sample': [4, 5, 6, 9, 10, 16, 17, 18, 19, 20, 21, 26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39, 44, 45],
    'Abundance': [1701, 4368, 1561, 9104, 3187, 2696, 1203, 9074, 3124, 20031, 10214, 6000, 2278, 9098, 14591, 279, 13760, 3485, 518, 30808, 34103, 2594, 47483, 44261, 21853, 4690],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_WT', 'Sig_Homo_HET'],
    'Type': ['F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F'],
}

# Create a DataFrame
df = pd.DataFrame(data)

# Box plot with specific colors using hex values
plt.figure(figsize=(10, 6))
sns.boxplot(x='Type', y='Abundance', hue='Genotype', data=df, palette={'Sig_Homo_HET': '#ADD8E6', 'Sig_WT': '#FFB6C1'})
plt.title('Abundance Box Plot')
plt.ylabel('Abundance')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 14
#       6 data = {
#       7     'Sample': [1, 2, 3, 7, 8, 11, 13, 14, 15, 22, 23, 24, 25, 30, 40, 41, 42, 43, 46, 47, 48, 49],
#       8     'Lactobacillus': [44381, 42758, 43620, 44576, 43701, 30982, 26114, 27176, 28842, 27690, 32981, 33292, 34044, 34339, 26302, 35700, 33459, 26380, 27021, 26176, 40092, 37526],
#       9     'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET'],
#      10     'Type': ['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C'],
#      11 }
#      13 # Create a DataFrame
# ---> 14 df = pd.DataFrame(data)
#      16 # Box plot with specific colors using hex values
#      17 plt.figure(figsize=(10, 6))
#
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/pandas/core/frame.py:708, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     702     mgr = self._init_mgr(
#     703         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     704     )
#     706 elif isinstance(data, dict):
#     707     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 708     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     709 elif isinstance(data, ma.MaskedArray):
#     710     from numpy.ma import mrecords
#
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/pandas/core/internals/construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/pandas/core/internals/construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/pandas/core/internals/construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data for feeding
data_F = {
    'sample': [4, 5, 6, 9, 10, 16, 17, 18, 19, 20, 21, 26, 27, 28, 29, 31, 32, 33, 34, 35, 36, 37, 38, 39, 44, 45],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_WT', 'Sig_Homo_HET'],
    'Lactobacillus': [1701, 4368, 1561, 9104, 3187, 2696, 1203, 9074, 3124, 20031, 10214, 6000, 2278, 9098, 14591, 279, 13760, 3485, 518, 30808, 34103, 2594, 47483, 44261, 21853, 4690],
}

# Sample data for control
data_C = {
    'sample': [1, 2, 3, 7, 8, 11, 13, 14, 15, 22, 23, 24, 25, 30, 40, 41, 42, 43, 46, 47, 48, 49],
    'Genotype': ['Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET',
                 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_Homo_HET', 'Sig_WT', 'Sig_Homo_HET', 'Sig_Homo_HET',
                 'Sig_Homo_HET'],
    'Lactobacillus': [44381, 42758, 43620, 44576, 43701, 30982, 26114, 27176, 28842, 27690, 32981, 33292, 34044, 34339, 26302, 35700, 33459, 26380, 27021, 26176, 40092, 37526],
}

# Combine feeding and control data into a single DataFrame
df_F = pd.DataFrame(data_F)
df_C = pd.DataFrame(data_C)
df_F['Dataset'] = 'Feeding'
df_C['Dataset'] = 'Control'
df_combined = pd.concat([df_C, df_F])  # Note the order change

# Melt the combined DataFrame for easy plotting
df_melted_combined = pd.melt(df_combined, id_vars=['Dataset', 'Genotype', 'sample'], value_vars=['Lactobacillus'],
                             var_name='Bacterial Species', value_name='Abundance')

# Set specific colors for Genotype
colors = {'Sig_Homo_HET': '#F8766D',  # Light Blue
          'Sig_WT': '#00BFC4'}

# Box plot for combined data with Control on the left and Feeding on the right
plt.figure(figsize=(15, 8))
sns.boxplot(x='Dataset', y='Abundance', hue='Genotype', data=df_melted_combined, palette=colors)
plt.title('Lactobacillus',fontsize = 18)
plt.ylabel('Abundance',fontsize = 18)  # Add y-axis label for clarity
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Show the plot
plt.show()
