# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read data from CSV files for feeding and control
df_F = pd.read_csv('taxa_abund_genus_F.csv', index_col=0).T
df_F['Escherichia_Shigella'] = pd.to_numeric(df_F['Escherichia_Shigella'], errors='coerce')
# df_F['Alphaproteobacteria'] = pd.to_numeric(df_F['Alphaproteobacteria'], errors='coerce')
# df_F['Bacilli'] = pd.to_numeric(df_F['Bacilli'], errors='coerce')
# df_F['Bacteroidia'] = pd.to_numeric(df_F['Bacteroidia'], errors='coerce')
# df_F['Clostridia'] = pd.to_numeric(df_F['Clostridia'], errors='coerce')
# # Gammaproteobacteria Mollicutes
# df_F['Gammaproteobacteria'] = pd.to_numeric(df_F['Gammaproteobacteria'], errors='coerce')
# df_F['Mollicutes'] = pd.to_numeric(df_F['Mollicutes'], errors='coerce')
df_F['Group'] = 'Feeding'

df_C = pd.read_csv('taxa_abund_genus_C.csv', index_col=0).T
df_C['Escherichia_Shigella'] = pd.to_numeric(df_C['Escherichia_Shigella'], errors='coerce')
# df_C['Alphaproteobacteria'] = pd.to_numeric(df_C['Alphaproteobacteria'], errors='coerce')
# df_C['Bacilli'] = pd.to_numeric(df_C['Bacilli'], errors='coerce')
# df_C['Bacteroidia'] = pd.to_numeric(df_C['Bacteroidia'], errors='coerce')
# df_C['Clostridia'] = pd.to_numeric(df_C['Clostridia'], errors='coerce')
# df_C['Gammaproteobacteria'] = pd.to_numeric(df_C['Gammaproteobacteria'], errors='coerce')
# df_C['Mollicutes'] = pd.to_numeric(df_C['Mollicutes'], errors='coerce')
df_C['Group'] = 'Control'

# Concatenate the DataFrames
df_concat = pd.concat([df_F, df_C])

# Actinobacteria
plt.figure(figsize=(16, 9))
ax = plt.axes()
# Set specific colors for Genotype
colors = {'Sig_Homo_HET': '#F8766D',  # Light Blue
          'Sig_WT': '#00BFC4'}
dot_colors = {'Sig_Homo_HET': 'black',  # Light Blue
          'Sig_WT': 'black'}
# Plot data from df_concat
sns.boxplot(x='Group', y='Escherichia_Shigella', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'],sym='')
# sns.boxplot(x='Group', y='Alphaproteobacteria', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'])
# Plot data from df_concat using boxplot
# sns.boxplot(x='Group', y='Escherichia_Shigella', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'])

# Add swarm plot on top of boxplot inside each box group
sns.swarmplot(x='Group', y='Escherichia_Shigella',hue='Genotype', data=df_concat, palette=dot_colors, order=['Control', 'Feeding'], dodge=True)


# Set labels and title
plt.title('Escherichia_Shigella',fontsize=18)
plt.xlabel('Group',fontsize=18)
plt.ylabel('Abundance',fontsize=18)

# Show the legend
plt.legend(title='Genotype')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)


# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1223/1439115704.py:45: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='Group', y='Escherichia_Shigella', data=df_concat, palette=dot_colors, order=['Control', 'Feeding'], dodge=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 45
#      39 sns.boxplot(x='Group', y='Escherichia_Shigella', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'],sym='')
#      40 # sns.boxplot(x='Group', y='Alphaproteobacteria', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'])
#      41 # Plot data from df_concat using boxplot
#      42 # sns.boxplot(x='Group', y='Escherichia_Shigella', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'])
#      43
#      44 # Add swarm plot on top of boxplot inside each box group
# ---> 45 sns.swarmplot(x='Group', y='Escherichia_Shigella', data=df_concat, palette=dot_colors, order=['Control', 'Feeding'], dodge=True)
#      48 # Set labels and title
#      49 plt.title('Escherichia_Shigella',fontsize=18)
#
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/seaborn/categorical.py:2650, in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2646 palette, hue_order = p._hue_backcompat(color, palette, hue_order)
#    2648 color = _default_color(ax.scatter, hue, color, kwargs)
# -> 2650 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2652 # XXX Copying possibly bad default decisions from original code for now
#    2653 kwargs.setdefault("zorder", 3)
#
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/seaborn/_oldcore.py:55, in SemanticMapping.map(cls, plotter, *args, **kwargs)
#      52 def map(cls, plotter, *args, **kwargs):
#      53     # This method is assigned the __init__ docstring
#      54     method_name = f"_{cls.__name__[:-7].lower()}_map"
# ---> 55     setattr(plotter, method_name, cls(plotter, *args, **kwargs))
#      56     return plotter
#
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/seaborn/_oldcore.py:148, in HueMapping.__init__(self, plotter, palette, order, norm)
#     145 elif map_type == "categorical":
#     147     cmap = norm = None
# --> 148     levels, lookup_table = self.categorical_mapping(
#     149         data, palette, order,
#     150     )
#     152 # --- Option 3: datetime mapping
#     153
#     154 else:
#     155     # TODO this needs actual implementation
#     156     cmap = norm = None
#
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/seaborn/_oldcore.py:227, in HueMapping.categorical_mapping(self, data, palette, order)
#     225     if any(missing):
#     226         err = "The palette dictionary is missing keys: {}"
# --> 227         raise ValueError(err.format(missing))
#     229     lookup_table = palette
#     231 else:
#
# ValueError: The palette dictionary is missing keys: {'Feeding', 'Control'}
