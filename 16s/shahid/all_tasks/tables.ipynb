# %%
import pandas as pd
in_path = "/home/xuan/BioinformaticTools/16s/shahid/all_tasks/Different_Time_Points/P11_COLON_WT_HomoHET/P11_COLON_WT_HomoHET.csv"
out_path = "/home/xuan/BioinformaticTools/16s/shahid/all_tasks/Different_Time_Points/P11_COLON_WT_HomoHET/P11_COLON_WT_HomoHET_NEC.csv"
# Read the CSV file into a pandas DataFrame
df = pd.read_csv(in_path)
# print(df)
column_name = 'Experiment'
value_to_filter = 'C'

# Create a new DataFrame without the desired rows
filtered_df = df[df[column_name] != value_to_filter]
print(filtered_df)
# # Save the modified DataFrame back to a CSV file
# df.to_csv('modified_file.csv', index=False)

def filter_element(column_name,value_to_filter,in_path,out_path):
    df = pd.read_csv(in_path)
    # Create a new DataFrame without the desired rows
    filtered_df = df[df[column_name] != value_to_filter]
    filtered_df.to_csv(out_path, index=False)
    return None
filter_element(column_name,value_to_filter,in_path,out_path)
C_out_path = "/home/xuan/BioinformaticTools/16s/shahid/all_tasks/Different_Time_Points/P11_COLON_WT_HomoHET/P11_COLON_WT_HomoHET_C.csv"
filter_element('Experiment',"NEC",in_path,C_out_path)
# Out:
#    #NAME Experiment Tissue type    DOL      Genotype
# 3   053A        NEC       colon  DOL11  Sig Homo_HET
# 4   054A        NEC       colon  DOL11  Sig Homo_HET
# 5   055A        NEC       colon  DOL11  Sig Homo_HET
# 6   056A        NEC       colon  DOL11  Sig Homo_HET
# 7   057A        NEC       colon  DOL11  Sig Homo_HET
# 11  061A        NEC       colon  DOL11  Sig Homo_HET
# 12  062A        NEC       colon  DOL11  Sig Homo_HET
# 13  063A        NEC       colon  DOL11  Sig Homo_HET
# 18  068A        NEC       colon  DOL11  Sig Homo_HET
# 19  069A        NEC       colon  DOL11  Sig Homo_HET
# 20  070A        NEC       colon  DOL11  Sig Homo_HET
# 21  071A        NEC       colon  DOL11        Sig WT
# 22  072A        NEC       colon  DOL11  Sig Homo_HET
# 27  077A        NEC       colon  DOL11        Sig WT
# 28  078A        NEC       colon  DOL11  Sig Homo_HET
# 29  079A        NEC       colon  DOL11  Sig Homo_HET
# 39  089A        NEC       colon  DOL11  Sig Homo_HET
# ...

# %%
import pandas as pd
otu_path  ="/home/xuan/BioinformaticTools/16s/shahid/all_tasks/Different_Time_Points/P8/genus_table_Umar_P8_MPD.csv"
otu_df = pd.read_csv(otu_path)
print(otu_df)
# Out:
#                                                   #NAME      1      2      3  \
# 0     Bacteria;Firmicutes;Bacilli;Lactobacillales;La...  79024  68214  75562
# 1     Bacteria;Proteobacteria;Gammaproteobacteria;En...    112    119     87
# 2     Bacteria;Proteobacteria;Gammaproteobacteria;Pa...   1437   1060   1513
# 3     Bacteria;Firmicutes;Bacilli;Bacillales;Staphyl...   1673   3455   3156
# 4     Bacteria;Firmicutes;Clostridia;Clostridiales;C...      0      0      0
# ...                                                 ...    ...    ...    ...
# 1025  Bacteria;Proteobacteria;Gammaproteobacteria;Ps...      0      0      0
# 1026  Bacteria;Firmicutes;Bacilli;Bacillales;Bacilla...      0      0      0
# 1027  Bacteria;Proteobacteria;Gammaproteobacteria;Be...      0      0      0
# 1028  Eukaryota;Euglenozoa;Kinetoplastea;Metakinetop...      0      0      0
# 1029  Bacteria;Proteobacteria;Alphaproteobacteria;Az...      0      0      0
#
# ...

# %%
grp_path  ="/home/xuan/BioinformaticTools/16s/shahid/all_tasks/Different_Time_Points/P8/P8_C.csv"
grp_df = pd.read_csv(grp_path)
# List of column names to keep
first_column_list = grp_df.iloc[:, 0].astype(str).tolist()
print(first_column_list)
# Filter the DataFrame to keep only the desired columns
fina_df = otu_df.filter(["#NAME"]+first_column_list)
print(fina_df)

def rebuild_otu(otu_path,grp_path,out_path):
    otu_df = pd.read_csv(otu_path)
    grp_df = pd.read_csv(grp_path)
    first_column_list = grp_df.iloc[:, 0].astype(str).tolist()
    fina_df = otu_df.filter(["#NAME"]+first_column_list)
    fina_df.to_csv(out_path, index=False)
    grp_df.to_csv(grp_path, index=False)
    print(fina_df)
    return None
# Out:
# ['1', '2', '3', '7', '8', '11', '12', '13', '14', '15', '22', '23', '24', '25', '30', '40', '41', '42', '43', '46', '47', '48', '49']
#                                                   #NAME      1      2      3  \
# 0     Bacteria;Firmicutes;Bacilli;Lactobacillales;La...  79024  68214  75562
# 1     Bacteria;Proteobacteria;Gammaproteobacteria;En...    112    119     87
# 2     Bacteria;Proteobacteria;Gammaproteobacteria;Pa...   1437   1060   1513
# 3     Bacteria;Firmicutes;Bacilli;Bacillales;Staphyl...   1673   3455   3156
# 4     Bacteria;Firmicutes;Clostridia;Clostridiales;C...      0      0      0
# ...                                                 ...    ...    ...    ...
# 1025  Bacteria;Proteobacteria;Gammaproteobacteria;Ps...      0      0      0
# 1026  Bacteria;Firmicutes;Bacilli;Bacillales;Bacilla...      0      0      0
# 1027  Bacteria;Proteobacteria;Gammaproteobacteria;Be...      0      0      0
# ...

# %%
# rebuild_otu(otu_path,grp_path,out_path)
path_otu = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/CONTROL/genus_table_Umar_MPD_optimized.csv"
grp_path = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/CONTROL/P11_P14_P28_COLON_WT_Homo_HET_CONTROL.csv"
out_otu_path = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/CONTROL/genus_table_Umar_MPD_control.csv"
rebuild_otu(path_otu,grp_path,out_otu_path)
# ./Colon/P11_P14_P28_COLON_WT_Homo_HET/NEC/P11_P14_P28_COLON_WT_Homo_HET_CONTROL.csv
# path_otu = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/NEC/genus_table_Umar_MPD_optimized.csv"
# grp_path = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/NEC/P11_P14_P28_COLON_WT_Homo_HET_NEC.csv"
# out_otu_path = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/NEC/genus_table_Umar_MPD_NEC.csv"
# rebuild_otu(path_otu,grp_path,out_otu_path)
# #./Colon/P11_P14_P28_COLON_WT_HomoHET/NEC/P11_P14_P28_COLON_WT_Homo_HET_NEC.csv
# # rebuild_otu(otu_path,grp_path,out_path)
# path_otu = "./Colon/P11_P14_P28_COLON_WT_HomoHET/CONTROL/genus_table_Umar_MPD_optimized.csv"
# grp_path = "./Colon/P11_P14_P28_COLON_WT_HomoHET/CONTROL/P11_P14_P28_COLON_WT_Homo_HET_CONTROL.csv"
# out_otu_path = "./Colon/P11_P14_P28_COLON_WT_HomoHET/CONTROL/genus_table_Umar_MPD_control.csv"
# rebuild_otu(path_otu,grp_path,out_otu_path)

# path_otu = "./Colon/P11_P14_P28_COLON_WT_HomoHET/NEC/genus_table_Umar_MPD_optimized.csv"
# grp_path = "./Colon/P11_P14_P28_COLON_WT_HomoHET/NEC/P11_P14_P28_COLON_WT_Homo_HET_NEC.csv"
# out_otu_path = "./Colon/P11_P14_P28_COLON_WT_HomoHET/NEC/genus_table_Umar_MPD_NEC.csv"
# rebuild_otu(path_otu,grp_path,out_otu_path)
# Out:
#                                                   #NAME   050A   051A   052A  \
# 0     Bacteria;Firmicutes;Bacilli;Lactobacillales;La...  11542  24269  28100
# 1     Bacteria;Proteobacteria;Gammaproteobacteria;En...   6782  13358   8280
# 2     Bacteria;Proteobacteria;Gammaproteobacteria;Pa...     53    102    116
# 3     Bacteria;Firmicutes;Bacilli;Bacillales;Staphyl...      0     16      0
# 4     Bacteria;Firmicutes;Clostridia;Clostridiales;C...      0      0      0
# ...                                                 ...    ...    ...    ...
# 1025  Bacteria;Proteobacteria;Gammaproteobacteria;Ps...      0      0      0
# 1026  Bacteria;Firmicutes;Bacilli;Bacillales;Bacilla...      0      0      0
# 1027  Bacteria;Proteobacteria;Gammaproteobacteria;Be...      0      0      0
# 1028  Eukaryota;Euglenozoa;Kinetoplastea;Metakinetop...      0      0      0
# 1029  Bacteria;Proteobacteria;Alphaproteobacteria;Az...      0      0      0
#
# ...

# %%
P11_otu = "./Different_Time_Points/P11_COLON_WT_Homo_HET/genus_table_Umar_MPD_P11_COLON_optimized.csv"
P11_grp_C = "./Different_Time_Points/P11_COLON_WT_Homo_HET/P11_COLON_WT_Homo_HET_C.csv"
P11_grp_NEC = "./Different_Time_Points/P11_COLON_WT_Homo_HET/P11_COLON_WT_Homo_HET_NEC.csv"
P11_otu_C = "./Different_Time_Points/P11_COLON_WT_Homo_HET/genus_table_Umar_MPD_P11_COLON_C.csv"
P11_otu_NEC = "./Different_Time_Points/P11_COLON_WT_Homo_HET/genus_table_Umar_MPD_P11_COLON_NEC.csv"
rebuild_otu(P11_otu,P11_grp_C,P11_otu_C)
rebuild_otu(P11_otu,P11_grp_NEC,P11_otu_NEC)

# %%
P11_otu = "./Different_Time_Points/P11_Ileal_WT_HomoHET/genus_table_Umar_MPD_P11_Ileal_optimized.csv"
P11_TI_grp_NEC = "./Different_Time_Points/P11_Ileal_WT_HomoHET/P11_Ileal_WT_HomoHET_NEC.csv"
P11_TI_otu_NEC = "./Different_Time_Points/P11_Ileal_WT_HomoHET/genus_table_Umar_Ileal_WT_HomoHET_NEC.csv"
rebuild_otu(P11_otu,P11_TI_grp_NEC,P11_TI_otu_NEC)

# %%
P11_colon_otu = "./P11_NEC_Non-NEC/genus_table_Umar_MPD_P11_COLON_optimized.csv"
P11_ti_otu = "./P11_NEC_Non-NEC/genus_table_Umar_MPD_P11_Ileal_optimized.csv"

P11_grp_colon_C = "./P11_NEC_Non-NEC/NEC_Colon _CONTROL.csv"
P11_grp_TI_C = "./P11_NEC_Non-NEC/NEC_TI_CONTROL.csv"

P11_grp_colon_NEC = "./P11_NEC_Non-NEC/NEC_Colon_NEC.csv"
P11_grp_TI_NEC = "./P11_NEC_Non-NEC/NEC_TI_NEC.csv"

P11_otu_colon_C = "./P11_NEC_Non-NEC/genus_table_Umar_MPD_P11_COLON_C.csv"
P11_otu_TI_C = "./P11_NEC_Non-NEC/genus_table_Umar_MPD_P11_Ileal_C.csv"

P11_otu_colon_NEC = "./P11_NEC_Non-NEC/genus_table_Umar_MPD_P11_COLON_NEC.csv"
P11_otu_TI_NEC = "./P11_NEC_Non-NEC/genus_table_Umar_MPD_P11_Ileal_NEC.csv"
# CONTROL
rebuild_otu(P11_colon_otu,P11_grp_colon_C,P11_otu_colon_C)
rebuild_otu(P11_ti_otu,P11_grp_TI_C,P11_otu_TI_C)
# NEC
rebuild_otu(P11_colon_otu,P11_grp_colon_NEC,P11_otu_colon_NEC)
rebuild_otu(P11_ti_otu,P11_grp_TI_NEC,P11_otu_TI_NEC)

# %%
P8_otu = "/home/xuan/BioinformaticTools/16s/shahid/all_tasks/Different_Time_Points/P8/genus_table_Umar_P8_MPD.csv"
P8_grp_C = "/home/xuan/BioinformaticTools/16s/shahid/all_tasks/Different_Time_Points/P8/P8_C.csv"
P8_grp_F = "/home/xuan/BioinformaticTools/16s/shahid/all_tasks/Different_Time_Points/P8/P8_F.csv"
P8_otu_C = "/home/xuan/BioinformaticTools/16s/shahid/all_tasks/Different_Time_Points/P8/genus_table_P8_C.csv"
P8_otu_F = "/home/xuan/BioinformaticTools/16s/shahid/all_tasks/Different_Time_Points/P8/genus_table_P8_F.csv"
rebuild_otu(P8_otu,P8_grp_C,P8_otu_C)
rebuild_otu(P8_otu,P8_grp_F,P8_otu_F)

# %%
in_path = "./Different_Time_Points/P11_Ileal_WT_Homo_HET/P11_Ileal_WT_Homo_HET.csv"
C_out_path = "./Different_Time_Points/P11_Ileal_WT_Homo_HET/P11_Ileal_WT_Homo_HET_C.csv"
NEC_out_path = "./Different_Time_Points/P11_Ileal_WT_Homo_HET/P11_Ileal_WT_Homo_HET_NEC.csv"
filter_element('Experiment',"NEC",in_path,C_out_path)
filter_element('Experiment',"C",in_path,NEC_out_path)

P11_otu = "./Different_Time_Points/P11_Ileal_WT_Homo_HET/genus_table_Umar_MPD_P11_Ileal_optimized.csv"
P11_grp_C = C_out_path
P11_grp_NEC = NEC_out_path
P11_otu_C = "./Different_Time_Points/P11_Ileal_WT_Homo_HET/genus_table_Umar_MP_C.csv"
P11_otu_NEC = "./Different_Time_Points/P11_Ileal_WT_Homo_HET/genus_table_Umar_MP_NEC.csv"
rebuild_otu(P11_otu,P11_grp_C,P11_otu_C)
rebuild_otu(P11_otu,P11_grp_NEC,P11_otu_NEC)

# %%
in_path = "./Different_Time_Points/P11_COLON_WT_Homo_HET/P11_Ileal_WT_Homo_HET.csv"
C_out_path = "./Different_Time_Points/P11_COLON_WT_Homo_HET/P11_Ileal_WT_Homo_HET_C.csv"
NEC_out_path = "./Different_Time_Points/P11_COLON_WT_Homo_HET/P11_Ileal_WT_Homo_HET_NEC.csv"
filter_element('Experiment',"NEC",in_path,C_out_path)
filter_element('Experiment',"C",in_path,NEC_out_path)

P11_otu = "./Different_Time_Points/P11_COLON_WT_Homo_HET/genus_table_Umar_MPD_P11_Ileal_optimized.csv"
P11_grp_C = C_out_path
P11_grp_NEC = NEC_out_path
P11_otu_C = "./Different_Time_Points/P11_COLON_WT_Homo_HET/genus_table_Umar_MP_C.csv"
P11_otu_NEC = "./Different_Time_Points/P11_COLON_WT_Homo_HET/genus_table_Umar_MP_NEC.csv"
rebuild_otu(P11_otu,P11_grp_C,P11_otu_C)
rebuild_otu(P11_otu,P11_grp_NEC,P11_otu_NEC)

# %%
in_path = "./Different_Time_Points/P11_COLON_WT_HomoHET/P11_COLON_WT_HomoHET.csv"
C_out_path = "./Different_Time_Points/P11_COLON_WT_HomoHET/P11_COLON_WT_HomoHET_C.csv"
NEC_out_path = "./Different_Time_Points/P11_COLON_WT_HomoHET/P11_COLON_WT_HomoHET_NEC.csv"
filter_element('Experiment',"NEC",in_path,C_out_path)
filter_element('Experiment',"C",in_path,NEC_out_path)

P11_otu = "./Different_Time_Points/P11_COLON_WT_HomoHET/genus_table_Umar_MPD_P11_COLON_optimized.csv"
P11_grp_C = C_out_path
P11_grp_NEC = NEC_out_path
P11_otu_C = "./Different_Time_Points/P11_COLON_WT_HomoHET/genus_table_Umar_MPD_P11_COLON_C.csv"
P11_otu_NEC = "./Different_Time_Points/P11_COLON_WT_HomoHET/genus_table_Umar_MPD_P11_COLON_NEC.csv"
rebuild_otu(P11_otu,P11_grp_C,P11_otu_C)
rebuild_otu(P11_otu,P11_grp_NEC,P11_otu_NEC)

# %%
in_path = "./Different_Time_Points/P11_COLON_WT_Homo_HET/P11_COLON_WT_Homo_HET.csv"
C_out_path = "./Different_Time_Points/P11_COLON_WT_Homo_HET/P11_COLON_WT_Homo_HET_C.csv"
NEC_out_path = "./Different_Time_Points/P11_COLON_WT_Homo_HET/P11_COLON_WT_Homo_HET_NEC.csv"
filter_element('Experiment',"NEC",in_path,C_out_path)
filter_element('Experiment',"C",in_path,NEC_out_path)

P11_otu = "./Different_Time_Points/P11_COLON_WT_Homo_HET/genus_table_Umar_MPD_P11_COLON_optimized.csv"
P11_grp_C = C_out_path
P11_grp_NEC = NEC_out_path
P11_otu_C = "./Different_Time_Points/P11_COLON_WT_HomoHET/genus_table_Umar_MPD_P11_COLON_C.csv"
P11_otu_NEC = "./Different_Time_Points/P11_COLON_WT_HomoHET/genus_table_Umar_MPD_P11_COLON_NEC.csv"
rebuild_otu(P11_otu,P11_grp_C,P11_otu_C)
rebuild_otu(P11_otu,P11_grp_NEC,P11_otu_NEC)

# %%
in_path = "./Different_Time_Points/P11_Ileal_WT_HomoHET/P11_Ileal_WT_HomoHET.csv"
C_out_path = "./Different_Time_Points/P11_Ileal_WT_HomoHET/P11_Ileal_WT_HomoHET_C.csv"
NEC_out_path = "./Different_Time_Points/P11_Ileal_WT_HomoHET/P11_Ileal_WT_HomoHET_NEC.csv"
filter_element('Experiment',"NEC",in_path,C_out_path)
filter_element('Experiment',"C",in_path,NEC_out_path)

P11_otu = "./Different_Time_Points/P11_Ileal_WT_HomoHET/genus_table_Umar_MPD_P11_Ileal_optimized.csv"
P11_grp_C = C_out_path
P11_grp_NEC = NEC_out_path
P11_otu_C = "./Different_Time_Points/P11_Ileal_WT_HomoHET/genus_table_Umar_MPD_P11_Ileal_C.csv"
P11_otu_F = "./Different_Time_Points/P11_Ileal_WT_HomoHET/genus_table_Umar_MPD_P11_Ileal_NEC.csv"
rebuild_otu(P11_otu,P11_grp_C,P11_otu_C)
rebuild_otu(P11_otu,P11_grp_NEC,P11_otu_NEC)

# %%
in_path = "./Different_Time_Points/P14_Ileal_WT_Homo_HET/P14_Ileal_WT_Homo_HET.csv"
C_out_path = "./Different_Time_Points/P14_Ileal_WT_Homo_HET/P14_Ileal_WT_Homo_HET_C.csv"
NEC_out_path = "./Different_Time_Points/P11_Ileal_WT_Homo_HET/P14_Ileal_WT_Homo_HET_NEC.csv"
filter_element('Experiment',"NEC",in_path,C_out_path)
filter_element('Experiment',"C",in_path,NEC_out_path)

P14_TI_otu = "./Different_Time_Points/P14_Ileal_WT_Homo_HET/genus_table_Umar_MPD_P14_Ileal_optimized.csv"
P14_TI_grp_C = C_out_path
P14_TI_grp_F = NEC_out_path
P14_TI_otu_C = "./Different_Time_Points/P14_Ileal_WT_Homo_HET/genus_table_Umar_MPD_P14_Ileal_C.csv"
P14_TI_otu_F = "./Different_Time_Points/P14_Ileal_WT_Homo_HET/genus_table_Umar_MPD_P14_Ileal_NEC.csv"
rebuild_otu(P14_TI_otu,P14_TI_grp_C,P14_TI_otu_C)
rebuild_otu(P14_TI_otu,P14_TI_grp_F,P14_TI_otu_F)

# %%
in_path = "./Different_Time_Points/P14_COLON_WT_Homo_HET/P14_COLON_WT_Homo_HET.csv"
C_out_path = "./Different_Time_Points/P14_COLON_WT_Homo_HET/P14_COLON_WT_Homo_HET_C.csv"
NEC_out_path = "./Different_Time_Points/P14_COLON_WT_Homo_HET/P14_COLON_WT_Homo_HET_NEC.csv"
filter_element('Experiment',"NEC",in_path,C_out_path)
filter_element('Experiment',"C",in_path,NEC_out_path)

P14_COL_otu = "./Different_Time_Points/P14_COLON_WT_Homo_HET/genus_table_Umar_MPD_P14_optimized.csv"
P14_COL_grp_C = C_out_path
P14_COL_grp_F = NEC_out_path
P14_COL_otu_C = "./Different_Time_Points/P14_COLON_WT_Homo_HET/genus_table_Umar_MPD_P14_C.csv"
P14_COL_otu_F = "./Different_Time_Points/P14_COLON_WT_Homo_HET/genus_table_Umar_MPD_P14_NEC.csv"
rebuild_otu(P14_COL_otu,P14_COL_grp_C,P14_COL_otu_C)
rebuild_otu(P14_COL_otu,P14_COL_grp_F,P14_COL_otu_F)

# %%
in_path = "./Different_Time_Points/P14_Ileal_WT_HomoHET/P14_Ileal_WT_HomoHET.csv"
C_out_path = "./Different_Time_Points/P14_Ileal_WT_HomoHET/P14_Ileal_WT_HomoHET_C.csv"
NEC_out_path = "./Different_Time_Points/P14_Ileal_WT_HomoHET/P14_Ileal_WT_HomoHET_NEC.csv"
filter_element('Experiment',"NEC",in_path,C_out_path)
filter_element('Experiment',"C",in_path,NEC_out_path)

P14_TI_HH_otu = "./Different_Time_Points/P14_Ileal_WT_HomoHET/genus_table_Umar_MPD_P14_Ileal_optimized.csv"
P14_TI_HH_grp_C = C_out_path
P14_TI_HH_grp_F = NEC_out_path
P14_TI_HH_otu_C = "./Different_Time_Points/P14_Ileal_WT_HomoHET/genus_table_Umar_MPD_P14_Ileal_C.csv"
P14_TI_HH_otu_F = "./Different_Time_Points/P14_Ileal_WT_HomoHET/genus_table_Umar_MPD_P14_Ileal_NEC.csv"
rebuild_otu(P14_TI_HH_otu,P14_TI_HH_grp_C,P14_TI_HH_otu_C)
rebuild_otu(P14_TI_HH_otu,P14_TI_HH_grp_F,P14_TI_HH_otu_F)

# %%
# rebuild_otu(otu_path,grp_path,out_path)
path_otu = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/CONTROL/genus_table_Umar_MPD_optimized.csv"
grp_path = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/CONTROL/P11_P14_P28_COLON_WT_Homo_HET_CONTROL.csv"
out_otu_path = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/CONTROL/genus_table_Umar_MPD_control.csv"
rebuild_otu(path_otu,grp_path,out_otu_path)
# ./Colon/P11_P14_P28_COLON_WT_Homo_HET/NEC/P11_P14_P28_COLON_WT_Homo_HET_CONTROL.csv
path_otu = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/NEC/genus_table_Umar_MPD_optimized.csv"
grp_path = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/NEC/P11_P14_P28_COLON_WT_Homo_HET_NEC.csv"
out_otu_path = "./Colon/P11_P14_P28_COLON_WT_Homo_HET/NEC/genus_table_Umar_MPD_control.csv"
rebuild_otu(path_otu,grp_path,out_otu_path)

# rebuild_otu(otu_path,grp_path,out_path)
path_otu = "./Colon/P11_P14_P28_COLON_WT_HomoHET/CONTROL/genus_table_Umar_MPD_optimized.csv"
grp_path = "./Colon/P11_P14_P28_COLON_WT_HomoHET/CONTROL/P11_P14_P28_COLON_WT_Homo_HET_CONTROL.csv"
out_otu_path = "./Colon/P11_P14_P28_COLON_WT_HomoHET/CONTROL/genus_table_Umar_MPD_control.csv"
rebuild_otu(path_otu,grp_path,out_otu_path)

path_otu = "./Colon/P11_P14_P28_COLON_WT_HomoHET/NEC/genus_table_Umar_MPD_optimized.csv"
grp_path = "./Colon/P11_P14_P28_COLON_WT_HomoHET/NEC/P11_P14_P28_COLON_WT_Homo_HET_NEC.csv"
out_otu_path = "./Colon/P11_P14_P28_COLON_WT_HomoHET/NEC/genus_table_Umar_MPD_NEC.csv"
rebuild_otu(path_otu,grp_path,out_otu_path)

# %%
# rebuild_otu(otu_path,grp_path,out_path)
path_otu = "./Ileal/P11_P14_P28_Ileal_WT_Homo_HET/CONTROL/genus_table_Umar_MPD_optimized.csv"
grp_path = "./Ileal/P11_P14_P28_Ileal_WT_Homo_HET/CONTROL/P11_P14_P28_COLON_WT_Homo_HET_CONTROL.csv"
out_otu_path = "./Ileal/P11_P14_P28_Ileal_WT_Homo_HET/CONTROL/genus_table_Umar_MPD_control.csv"
rebuild_otu(path_otu,grp_path,out_otu_path)

path_otu = "./Ileal/P11_P14_P28_Ileal_WT_Homo_HET/NEC/genus_table_Umar_MPD_optimized.csv"
grp_path = "./Ileal/P11_P14_P28_Ileal_WT_Homo_HET/NEC/P11_P14_P28_COLON_WT_Homo_HET_NEC.csv"
out_otu_path = "./Ileal/P11_P14_P28_Ileal_WT_Homo_HET/NEC/genus_table_Umar_MPD_NEC.csv"
rebuild_otu(path_otu,grp_path,out_otu_path)

# rebuild_otu(otu_path,grp_path,out_path)
path_otu = "./Ileal/P11_P14_P28_Ileal_WT_HomoHET/CONTROL/genus_table_Umar_MPD_optimized.csv"
grp_path = "./Ileal/P11_P14_P28_Ileal_WT_HomoHET/CONTROL/P11_P14_P28_COLON_WT_Homo_HET_CONTROL.csv"
out_otu_path = "./Ileal/P11_P14_P28_Ileal_WT_HomoHET/CONTROL/genus_table_Umar_MPD_NEC.csv"
rebuild_otu(path_otu,grp_path,out_otu_path)
# Colon/P11_P14_P28_Ileal_WT_Homo_HET/CONTROL
path_otu = "./Ileal/P11_P14_P28_Ileal_WT_HomoHET/NEC/genus_table_Umar_MPD_optimized.csv"
grp_path = "./Ileal/P11_P14_P28_Ileal_WT_HomoHET/NEC/P11_P14_P28_COLON_WT_Homo_HET_NEC.csv"
out_otu_path = "./Ileal/P11_P14_P28_Ileal_WT_HomoHET/NEC/genus_table_Umar_MPD_NEC.csv"
rebuild_otu(path_otu,grp_path,out_otu_path)
