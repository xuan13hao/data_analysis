# %% [markdown]
# Loading datasets

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
# Read the CSV file
EC_output_csv_file = "EC_func_description.csv"
columns_to_extract = ['function', 'description']
df_EC = pd.read_csv('description/EC_pred_metagenome_unstrat_descrip.tsv',delimiter='\t', usecols=columns_to_extract)
df_EC.to_csv(EC_output_csv_file, index=False)
df_EC.head(10)
# Out:
#        function                                 description
# 0    EC:1.1.1.1                       Alcohol dehydrogenase
# 1  EC:1.1.1.100  3-oxoacyl-[acyl-carrier-protein] reductase
# 2  EC:1.1.1.102              3-dehydrosphinganine reductase
# 3  EC:1.1.1.103                 L-threonine 3-dehydrogenase
# 4  EC:1.1.1.105    All-trans-retinol dehydrogenase (NAD(+))
# 5  EC:1.1.1.107                   Pyridoxal 4-dehydrogenase
# 6  EC:1.1.1.108                   Carnitine 3-dehydrogenase
# 7   EC:1.1.1.11                D-arabinitol 4-dehydrogenase
# 8  EC:1.1.1.122              D-threo-aldose 1-dehydrogenase
# 9  EC:1.1.1.125         2-deoxy-D-gluconate 3-dehydrogenase

# %% [markdown]
# Build function and description

# %%
K_output_csv_file = "K_func_description.csv"
columns_to_extract = ['function', 'description']
df_K = pd.read_csv('description/K_pred_metagenome_unstrat_descrip.tsv',delimiter='\t', usecols=columns_to_extract)
df_K.to_csv(K_output_csv_file, index=False)
df_K.head(10)
# Out:
#   function                                        description
# 0   K00001  E1.1.1.1, adh; alcohol dehydrogenase [EC:1.1.1.1]
# 1   K00002  AKR1A1, adh; alcohol dehydrogenase (NADP+) [EC...
# 2   K00003    E1.1.1.3; homoserine dehydrogenase [EC:1.1.1.3]
# 3   K00004  BDH, butB; (R,R)-butanediol dehydrogenase / me...
# 4   K00005          gldA; glycerol dehydrogenase [EC:1.1.1.6]
# 5   K00006  GPD1; glycerol-3-phosphate dehydrogenase (NAD+...
# 6   K00007   dalD; D-arabinitol 4-dehydrogenase [EC:1.1.1.11]
# 7   K00008  SORD, gutB; L-iditol 2-dehydrogenase [EC:1.1.1...
# 8   K00009  mtlD; mannitol-1-phosphate 5-dehydrogenase [EC...
# 9   K00010  iolG; myo-inositol 2-dehydrogenase / D-chiro-i...

# %%
pwy_output_csv_file = "pwy_func_description.csv"
columns_to_extract = ['pathway', 'description']
df_pwy = pd.read_csv('description/path_abun_unstrat_descrip.tsv',delimiter='\t', usecols=columns_to_extract)
df_pwy.to_csv(pwy_output_csv_file, index=False)
df_pwy.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2302 entries, 0 to 2301
# Columns: 387 entries, function to VS049
# dtypes: float64(385), object(2)
# memory usage: 6.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7602 entries, 0 to 7601
# Columns: 387 entries, function to VS049
# dtypes: float64(385), object(2)
# memory usage: 22.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Columns: 387 entries, pathway to VS049
# dtypes: float64(385), object(2)
# memory usage: 1.2+ MB
