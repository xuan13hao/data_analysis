# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read data from CSV files for feeding and control
df_F = pd.read_csv('taxa_abund_F_Phlum.csv', index_col=0).T
df_F['Bacteroidetes'] = pd.to_numeric(df_F['Bacteroidetes'], errors='coerce')
df_F['Proteobacteria'] = pd.to_numeric(df_F['Proteobacteria'], errors='coerce')
df_F['Tenericutes'] = pd.to_numeric(df_F['Tenericutes'], errors='coerce')
# df_F['Bacteroidia'] = pd.to_numeric(df_F['Bacteroidia'], errors='coerce')
# df_F['Clostridia'] = pd.to_numeric(df_F['Clostridia'], errors='coerce')
# # Gammaproteobacteria Mollicutes
# df_F['Gammaproteobacteria'] = pd.to_numeric(df_F['Gammaproteobacteria'], errors='coerce')
# df_F['Mollicutes'] = pd.to_numeric(df_F['Mollicutes'], errors='coerce')
df_F['Group'] = 'Feeding'

df_C = pd.read_csv('taxa_abund_C_Phlum.csv', index_col=0).T
df_C['Bacteroidetes'] = pd.to_numeric(df_C['Bacteroidetes'], errors='coerce')
df_C['Proteobacteria'] = pd.to_numeric(df_C['Proteobacteria'], errors='coerce')
df_C['Tenericutes'] = pd.to_numeric(df_C['Tenericutes'], errors='coerce')
# df_C['Bacteroidia'] = pd.to_numeric(df_C['Bacteroidia'], errors='coerce')
# df_C['Clostridia'] = pd.to_numeric(df_C['Clostridia'], errors='coerce')
# df_C['Gammaproteobacteria'] = pd.to_numeric(df_C['Gammaproteobacteria'], errors='coerce')
# df_C['Mollicutes'] = pd.to_numeric(df_C['Mollicutes'], errors='coerce')
df_C['Group'] = 'Control'

# Concatenate the DataFrames
df_concat = pd.concat([df_F, df_C])

# Actinobacteria
plt.figure(figsize=(16, 9))
ax = plt.axes()
# Set specific colors for Genotype
colors = {'Sig_Homo_HET': '#F8766D',  # Light Blue
          'Sig_WT': '#00BFC4'}
dot_colors = {'Sig_Homo_HET': 'black',  # Light Blue
          'Sig_WT': 'black'}
# Plot data from df_concat
sns.boxplot(x='Group', y='Bacteroidetes', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'],sym='')
# sns.boxplot(x='Group', y='Alphaproteobacteria', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'])
# Plot data from df_concat using boxplot
# sns.boxplot(x='Group', y='Escherichia_Shigella', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'])

# Add swarm plot on top of boxplot inside each box group
sns.swarmplot(x='Group', y='Bacteroidetes',hue='Genotype', data=df_concat, palette=dot_colors, order=['Control', 'Feeding'], dodge=True,legend=False)


# Set labels and title
plt.title('Bacteroidetes',fontsize=18)
plt.xlabel('Group',fontsize=18)
plt.ylabel('Abundance',fontsize=18)

# Show the legend
plt.legend(title='Genotype')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Actinobacteria
plt.figure(figsize=(16, 9))
ax = plt.axes()
# Set specific colors for Genotype
colors = {'Sig_Homo_HET': '#F8766D',  # Light Blue
          'Sig_WT': '#00BFC4'}
dot_colors = {'Sig_Homo_HET': 'black',  # Light Blue
          'Sig_WT': 'black'}
# Plot data from df_concat
sns.boxplot(x='Group', y='Proteobacteria', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'],sym='')
# sns.boxplot(x='Group', y='Alphaproteobacteria', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'])
# Plot data from df_concat using boxplot
# sns.boxplot(x='Group', y='Escherichia_Shigella', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'])

# Add swarm plot on top of boxplot inside each box group
sns.swarmplot(x='Group', y='Proteobacteria',hue='Genotype', data=df_concat, palette=dot_colors, order=['Control', 'Feeding'], dodge=True,legend=False)


# Set labels and title
plt.title('Proteobacteria',fontsize=18)
plt.xlabel('Group',fontsize=18)
plt.ylabel('Abundance',fontsize=18)

# Show the legend
plt.legend(title='Genotype')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Planctomycetes
plt.figure(figsize=(16, 9))
ax = plt.axes()
# Set specific colors for Genotype
colors = {'Sig_Homo_HET': '#F8766D',  # Light Blue
          'Sig_WT': '#00BFC4'}
dot_colors = {'Sig_Homo_HET': 'black',  # Light Blue
          'Sig_WT': 'black'}
# Plot data from df_concat
sns.boxplot(x='Group', y='Tenericutes', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'],sym='')
# sns.boxplot(x='Group', y='Alphaproteobacteria', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'])
# Plot data from df_concat using boxplot
# sns.boxplot(x='Group', y='Escherichia_Shigella', hue='Genotype', data=df_concat, ax=ax, palette=colors, width=0.8, order=['Control', 'Feeding'])

# Add swarm plot on top of boxplot inside each box group
sns.swarmplot(x='Group', y='Tenericutes',hue='Genotype', data=df_concat, palette=dot_colors, order=['Control', 'Feeding'], dodge=True,legend=False)


# Set labels and title
plt.title('Tenericutes',fontsize=18)
plt.xlabel('Group',fontsize=18)
plt.ylabel('Abundance',fontsize=18)

# Show the legend
plt.legend(title='Genotype')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/xuan_cuda/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Planctomycetes'
#
# The above exception was the direct cause of the following exception:
#
# ...
