# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
otus_data = pd.read_csv('data_normalized.csv')
metadata = pd.read_csv('P8_C_F.csv')
otus_data.head(10)
# Out:
#                            #NAME             1             2             3
# 0                  Lactobacillus  8.897736e+06  8.567618e+06  8.742705e+06  \
# 1           Escherichia_Shigella  1.444014e+04  1.423959e+04  7.019514e+03
# 2                     Muribacter  1.642566e+05  1.349752e+05  1.772929e+05
# 3                 Staphylococcus  1.772929e+05  4.336054e+05  3.461623e+05
# 4                  Streptococcus  5.653717e+05  5.900403e+05  5.286697e+05
# 5                   Enterococcus  1.062955e+04  2.807806e+03  1.403903e+03
# 6                    Pseudomonas  0.000000e+00  2.005575e+02  2.005575e+02
# 7  Lachnospiraceae_NK4A136_group  4.612824e+03  1.343736e+04  1.403903e+04
# 8                 Muribaculaceae  3.228977e+04  5.856280e+04  3.329255e+04
# 9                Lachnospiraceae  1.805018e+03  4.612824e+03  4.011151e+03
#
#               4             5             6             7             8
# ...

# %%
otus_data = otus_data.transpose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 otus_data = otus_data.transpose()
#
# NameError: name 'otus_data' is not defined
